# %% [markdown]
# #**Loganathan Creating a New Note Book**
# ##_Understanding the magic commads_
# ###`Giving colour for my name `
# $${\color{red}Loganathan Quote:-I like RED}$$
#
# ####Team photo
# ![Copyright!!](https://fpimages.withfloats.com/actual/6936e213e40c3ddda3969dd0.jpeg)

# %%
# %sql
--Task 2
CREATE VOLUME IF NOT EXISTS workspace.default.logan_datalake;
CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics;

# %%
dbutils.notebook.run(
  "/Workspace/Users/loganathansundaramsa@gmail.com/dataengg_inc_learning/Logan_fundamentals_pract/Task_Child",
  60
)

# %%
# %fs ls /Volumes/workspace/default/usage_metrics/

# %%
# Read the first 1024 bytes and display the first 2 lines
head_content = dbutils.fs.head(
    "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",
    1024
)
print('\n'.join(head_content.split('\n')[:2]))

# %%
# %fs head /Volumes/workspace/default/usage_metrics/mobile_os_usage.csv

# %%
df1 = spark.read.option("header", "true").csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
df1.display()

# %%
# %python
df_clean = df1.withColumnRenamed("Mobile Operating System", "mobile_operating_system") \
              .withColumnRenamed("Percent of Usage", "percent_of_usage")

df_clean.write.mode("overwrite").saveAsTable("default.mobile_os_usage")

# %%
# Task 7
df2 = spark.read.table("default.mobile_os_usage")
df2.display()

# %%
#Task8
df = spark.sql("select * from default.mobile_os_usage")
df.display()

# %%
#Task9
def convert_lower_string_to_upper(input):
    return input.upper()

convert_lower_string_to_upper('nathan')

# %%
#Task 10
# %pip install pandas

# %%
import pandas as pd
#Task 11
df = spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv", header=True)
df.display()

# %%
# %sh 
echo "Magic commands tasks completed"
